# %%
import pandas as pd
import numpy as np 
import os

# %%
one = pd.read_csv(r"Balance_sheet_2013_30K_5M.csv",encoding='latin1')
one.head()
# Out:
#    Incorporation Status\nStatus d'incorporation  Naics code\ncode Scian  \
# 0                                             2                      11
# 1                                             2                      11
# 2                                             2                      11
# 3                                             2                      11
# 4                                             2                      11
#
#    Province\nCanada  Total assets\nActif total  \
# 0                 0                     1749.7
# 1                10                     1070.4
# 2                11                     1917.8
# 3                12                      952.2
# 4                13                     1149.4
#
#   Quality Indicator\nIndicateurs de qualité  \
# 0                                         A
# 1                                         A
# 2                                         A
# 3                                         A
# ...

# %%
# enconding used is latin to avoid unicode error 
missing_values = one.isnull().sum()
missing_values[0:82]
# Out:
# Incorporation Status\nStatus d'incorporation                                             0
# Naics code\ncode Scian                                                                   0
# Province\nCanada                                                                         0
# Total assets\nActif total                                                                0
# Quality Indicator\nIndicateurs de qualité                                                0
#                                                                                         ..
# Bottom Quartile Total equity\nQuart inférieur Avoir des actionnaires en valeur totale    0
# Lower Middle Total equity\n2e quart Avoir des actionnaires en valeur totale              0
# Upper Middle Total equity\n3e quart Avoir des actionnaires en valeur totale              0
# Top quartile Total equity\nQuart supérieur Avoir des actionnaires en valeur totale       0
# ...

# %%
# our data set not contain any missiling values
# looking for duplicates
print(one.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 24934    False
# 24935    False
# 24936    False
# 24937    False
# 24938    False
# Length: 24939, dtype: bool

# %%
#there is no duplicates so make sure we use drop the duplicates 
one.drop_duplicates(inplace = True)
print(one.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 24934    False
# 24935    False
# 24936    False
# 24937    False
# 24938    False
# Length: 24939, dtype: bool
